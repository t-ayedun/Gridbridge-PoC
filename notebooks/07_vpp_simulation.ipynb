# %% [markdown]
# # 07: Virtual Power Plant (VPP) Aggregation & Open-Meteo Weather
# **Purpose**: Solar radiation forecasting and 24-hr battery storage dispatch simulation.
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
