# %% [markdown]
# # 05: World Bank Nigeria DRE Atlas Settlement Analysis
# **Purpose**: Settlement population, energy demand, and electrification status across 154k+ Nigerian settlements.
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
