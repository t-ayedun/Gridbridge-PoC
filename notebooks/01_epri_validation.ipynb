# %% [markdown]
# # 01: EPRI J1 Feeder OpenDSS Power Flow Validation
# **Purpose**: EPRI J1 feeder load flow simulation and low-voltage constraint identification (<0.95 p.u.).
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
