# %% [markdown]
# # 03: OpenStreetMap Power Infrastructure Digital Twin
# **Purpose**: OSM power lines, substations, and generator nodes extraction for synthetic digital twin creation.
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
