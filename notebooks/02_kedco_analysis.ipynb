# %% [markdown]
# # 02: KEDCO GIS Network & Transformer Profiling
# **Purpose**: Kano Electricity Distribution Company (KEDCO) MV line GeoJSON and transformer location analysis.
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
