# %% [markdown]
# # 06: Off-Grid Solar Mini-Grid Candidate Optimization
# **Purpose**: Islanding mode, solar PV sizing, and battery dispatch model for rural mini-grids.
#
# ---

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root in python path
sys.path.append('..')
from config.constants import DATA_RAW_DIR, DATA_PROCESSED_DIR

print('Workspace configured. Ready for experimentation.')
